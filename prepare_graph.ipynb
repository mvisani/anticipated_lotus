# %%
import grape
# Out:
# 2024-01-18 16:52:53.509115: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:pykeen.utils:Using opt_einsum

# %% [markdown]
# # Load lotus

# %%
from grape import Graph

# %%
lotus = Graph.from_csv(
    node_path="./data/lotus/lotus_nodes.csv",
    node_list_separator=",",
    node_list_header=True,
    nodes_column_number=1,
    node_list_node_types_column_number=2,
    edge_path="./data/lotus/lotus_edges.csv",
    edge_list_separator=",",
    edge_list_header=True,
    sources_column_number=1,
    destinations_column_number=2,
    #weights_column_number=3,
    edge_list_edge_types_column_number=4,
    #directed=False,
    directed=True,
)

# %%
species = Graph.from_csv(
    node_path="./data/species/species_nodes.csv",
    node_list_separator=",",
    node_list_header=True,
    nodes_column_number=1,
    node_list_node_types_column_number=2,
    edge_path="./data/species/species_edges.csv",
    edge_list_separator=",",
    edge_list_header=True,
    sources_column_number=1,
    destinations_column_number=2,
    edge_list_edge_types_column_number=3,
    #weights_column_number=4,
    directed=True,
    #directed=False,
)

# %%
molecules_to_chemont = Graph.from_csv(
    node_path="./data/molecules/mol_to_chemont_nodes.csv",
    node_list_separator=",",
    node_list_header=True,
    nodes_column_number=1,
    node_list_node_types_column_number=2,
    edge_path="./data/molecules/mol_to_chemont_edges.csv",
    edge_list_separator=",",
    edge_list_header=True,
    sources_column_number=1,
    destinations_column_number=2,
    edge_list_edge_types_column_number=3,
    #weights_column_number=4,
    directed=True,
    #directed=False,
)

# %%
chemont = Graph.from_csv(
    node_path="./data/molecules/chemont_nodes.csv",
    node_list_separator="\t",
    node_list_header=True,
    nodes_column_number=1,
    node_list_node_types_column_number=3,
    edge_path="./data/molecules/chemont_edges.csv",
    edge_list_separator=",",
    edge_list_header=True,
    sources_column_number=1,
    destinations_column_number=2,
    edge_list_edge_types_column_number=3,
    #weights_column_number=4,
    #directed=False,
    directed=True,
)

# %%
molecules_to_np = Graph.from_csv(
    node_path="./data/molecules/mol_to_np_nodes.csv",
    node_list_separator="\t",
    node_list_header=True,
    nodes_column_number=1,
    node_list_node_types_column_number=2,
    edge_path="./data/molecules/mol_to_np_edges.csv",
    edge_list_separator="\t",
    edge_list_header=True,
    sources_column_number=1,
    destinations_column_number=2,
    edge_list_edge_types_column_number=3,
    #directed=False,
    directed=True,
)

# %%
chemicals = chemont|molecules_to_chemont

# %%
chemical_with_np_classifier = chemicals|molecules_to_np

# %%
chemicals_and_lotus = chemical_with_np_classifier|lotus

# %%
full_graph = chemicals_and_lotus|species

# %%
full_graph
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>((((Graph | Graph) | Graph) | Graph) | Graph)</h2><p class="paragraph">The directed graph ((((Graph | Graph) | Graph) | Graph) | Graph) has 276.08K heterogeneous nodes and 1.02M heterogeneous edges. The RAM requirements for the nodes and edges data structures are 30.68MB and 6.29MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 0, the maximum node degree is 2.57K, the mode degree is 3, the mean degree is 3.70 and the node degree median is 3.</p><p class="paragraph">The nodes with the highest degree centrality are <a href='https://www.wikidata.org/wiki/Q121802' target='_blank' title='Go to WikiData to get more informations about wd:Q121802'>wd:Q121802</a> (degree 2.57K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), <a href='https://www.wikidata.org/wiki/Q409478' target='_blank' title='Go to WikiData to get more informations about wd:Q409478'>wd:Q409478</a> (degree 1.73K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), <a href='https://www.wikidata.org/wiki/Q425004' target='_blank' title='Go to WikiData to get more informations about wd:Q425004'>wd:Q425004</a> (degree 1.31K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), <a href='https://www.wikidata.org/wiki/Q393336' target='_blank' title='Go to WikiData to get more informations about wd:Q393336'>wd:Q393336</a> (degree 1.16K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>) and <a href='https://www.wikidata.org/wiki/Q415011' target='_blank' title='Go to WikiData to get more informations about wd:Q415011'>wd:Q415011</a> (degree 1.13K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a> (226.38K nodes, 82.00%) and <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a> (49.70K nodes, 18.00%). The RAM requirement for the node types  ...
# <li><p class="paragraph">Group with 2 nodes (degree 31 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q110079913' target='_blank' title='Go to WikiData to get more informations about wd:Q110079913'>wd:Q110079913</a> and <a href='https://www.wikidata.org/wiki/Q104251872' target='_blank' title='Go to WikiData to get more informations about wd:Q104251872'>wd:Q104251872</a>.</p></li>
# <li><p class="paragraph">Group with 4 nodes (degree 14 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q105225037' target='_blank' title='Go to WikiData to get more informations about wd:Q105225037'>wd:Q105225037</a>, <a href='https://www.wikidata.org/wiki/Q105193903' target='_blank' title='Go to WikiData to get more informations about wd:Q105193903'>wd:Q105193903</a>, <a href='https://www.wikidata.org/wiki/Q105302721' target='_blank' title='Go to WikiData to get more informations about wd:Q105302721'>wd:Q105302721</a> and <a href='https://www.wikidata.org/wiki/Q105139889' target='_blank' title='Go to WikiData to get more informations about wd:Q105139889'>wd:Q105139889</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 25 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q72437451' target='_blank' title='Go to WikiData to get more informations about wd:Q72437451'>wd:Q72437451</a> and <a href='https://www.wikidata.org/wiki/Q104666246' target='_blank' title='Go to WikiData to get more informations about wd:Q104666246'>wd:Q104666246</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 22 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q104392734' target='_blank' title='Go to WikiData to get more informations about wd:Q104392734'>wd:Q104392734</a> and <a href='https://www.wikidata.org/wiki/Q27166443' target='_blank' title='Go to WikiData to get more informations about wd:Q27166443'>wd:Q27166443</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 22 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q412223' target='_blank' title='Go to WikiData to get more informations about wd:Q412223'>wd:Q412223</a> and <a href='https://www.wikidata.org/wiki/Q111226215' target='_blank' title='Go to WikiData to get more informations about wd:Q111226215'>wd:Q111226215</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 14 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q105136788' target='_blank' title='Go to WikiData to get more informations about wd:Q105136788'>wd:Q105136788</a>, <a href='https://www.wikidata.org/wiki/Q105196517' target='_blank' title='Go to WikiData to get more informations about wd:Q105196517'>wd:Q105196517</a> and <a href='https://www.wikidata.org/wiki/Q105132682' target='_blank' title='Go to WikiData to get more informations about wd:Q105132682'>wd:Q105132682</a>.</p></li>
# <li><p class="paragraph">Group with 4 nodes (degree 10 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q105228959' target='_blank' title='Go to WikiData to get more informations about wd:Q105228959'>wd:Q105228959</a>, <a href='https://www.wikidata.org/wiki/Q104919583' target='_blank' title='Go to WikiData to get more informations about wd:Q104919583'>wd:Q104919583</a>, <a href='https://www.wikidata.org/wiki/Q104919581' target='_blank' title='Go to WikiData to get more informations about wd:Q104919581'>wd:Q104919581</a> and <a href='https://www.wikidata.org/wiki/Q104919580' target='_blank' title='Go to WikiData to get more informations about wd:Q104919580'>wd:Q104919580</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 11 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q104667387' target='_blank' title='Go to WikiData to get more informations about wd:Q104667387'>wd:Q104667387</a>, <a href='https://www.wikidata.org/wiki/Q104667384' target='_blank' title='Go to WikiData to get more informations about wd:Q104667384'>wd:Q104667384</a> and <a href='https://www.wikidata.org/wiki/Q104667383' target='_blank' title='Go to WikiData to get more informations about wd:Q104667383'>wd:Q104667383</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 11 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q104395964' target='_blank' title='Go to WikiData to get more informations about wd:Q104395964'>wd:Q104395964</a>, <a href='https://www.wikidata.org/wiki/Q104395963' target='_blank' title='Go to WikiData to get more informations about wd:Q104395963'>wd:Q104395963</a> and <a href='https://www.wikidata.org/wiki/Q27105891' target='_blank' title='Go to WikiData to get more informations about wd:Q27105891'>wd:Q27105891</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 10 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q105238368' target='_blank' title='Go to WikiData to get more informations about wd:Q105238368'>wd:Q105238368</a>, <a href='https://www.wikidata.org/wiki/Q105145014' target='_blank' title='Go to WikiData to get more informations about wd:Q105145014'>wd:Q105145014</a> and <a href='https://www.wikidata.org/wiki/Q105145015' target='_blank' title='Go to WikiData to get more informations about wd:Q105145015'>wd:Q105145015</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 10 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q27279099' target='_blank' title='Go to WikiData to get more informations about wd:Q27279099'>wd:Q27279099</a>, <a href='https://www.wikidata.org/wiki/Q105027054' target='_blank' title='Go to WikiData to get more informations about wd:Q105027054'>wd:Q105027054</a> and <a href='https://www.wikidata.org/wiki/Q105123190' target='_blank' title='Go to WikiData to get more informations about wd:Q105123190'>wd:Q105123190</a>.</p></li>
# <li><p class="paragraph">Group with 3 nodes (degree 10 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q104995037' target='_blank' title='Go to WikiData to get more informations about wd:Q104995037'>wd:Q104995037</a>, <a href='https://www.wikidata.org/wiki/Q104995039' target='_blank' title='Go to WikiData to get more informations about wd:Q104995039'>wd:Q104995039</a> and <a href='https://www.wikidata.org/wiki/Q104995032' target='_blank' title='Go to WikiData to get more informations about wd:Q104995032'>wd:Q104995032</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 14 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q82114008' target='_blank' title='Go to WikiData to get more informations about wd:Q82114008'>wd:Q82114008</a> and <a href='https://www.wikidata.org/wiki/Q15634172' target='_blank' title='Go to WikiData to get more informations about wd:Q15634172'>wd:Q15634172</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 13 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>): <a href='https://www.wikidata.org/wiki/Q27159234' target='_blank' title='Go to WikiData to get more informations about wd:Q27159234'>wd:Q27159234</a> and <a href='https://www.wikidata.org/wiki/Q105143574' target='_blank' title='Go to WikiData to get more informations about wd:Q105143574'>wd:Q105143574</a>.</p></li></ol><p class="paragraph">And other 27 isomorphic node groups.</p></div>

# %%
full_graph.dump_nodes(
    path="./data/full_lotus_nodes.csv",
    header=True,
    nodes_column_number=0,
    nodes_column="nodes",
    node_types_column_number=1,
    node_type_column="type"
)

# %%
full_graph.dump_edges(
    path="./data/full_lotus_edges.csv",
    header=True,
    directed=True,
    edge_types_column_number=2,
    edge_type_column='type',
)

# %%
full_graph.to_undirected()
# Out:
# <div class="graph-report"><style>.graph-report li {margin: 0.5em 0 0.5em 0;}.graph-report .paragraph {text-align: justify;word-break: break-all;}.graph-report .small-columns {column-count: 4;column-gap: 2em;}.graph-report .medium-columns {column-count: 3;column-gap: 2em;}.graph-report .large-columns {column-count: 2;column-gap: 2em;}.graph-report .single-column {}@media only screen and (max-width: 600px) {.graph-report .small-columns {column-count: 1;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 600px) and (max-width: 800px) {.graph-report .small-columns {column-count: 2;}.graph-report .medium-columns {column-count: 1;}.graph-report .large-columns {column-count: 1;}}@media only screen and (min-width: 800px) and (max-width: 1024px) {.graph-report .small-columns {column-count: 3;}.graph-report .medium-columns {column-count: 2;}.graph-report .large-columns {column-count: 1;}}</style><h2>((((Graph | Graph) | Graph) | Graph) | Graph)</h2><p class="paragraph">The undirected graph ((((Graph | Graph) | Graph) | Graph) | Graph) has 276.08K heterogeneous nodes and 1.02M heterogeneous edges. The graph is connected, that is, it is composed of a single connected component that includes all nodes and edges. The RAM requirements for the nodes and edges data structures are 30.68MB and 10.38MB respectively.</p><h3 style="margin: 1em 0 0 0;">Degree centrality</h3><p class="paragraph">The minimum node degree is 1, the maximum node degree is 9.91K, the mode degree is 3, the mean degree is 7.40 and the node degree median is 3.</p><p class="paragraph">The nodes with the highest degree centrality are CHEMONTID:0001553 (degree 9.91K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), Oleanane triterpenoids (degree 6.69K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), CHEMONTID:0001550 (degree 6.57K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>), CHEMONTID:0001551 (degree 5.71K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>) and CHEMONTID:0002358 (degree 5.15K and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>).</p><h3 style="margin: 1em 0 0 0;">Node types</h3><p class="paragraph">The graph has 2 node types, which are <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a> (226.38K nodes, 82.00%) and <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a> (49.70K nodes, 18.00%). The RAM requirement for the node types data structure is 14.36MB.</p><h3 style="margin: 1em 0 0 0;">Edge types</h3><p class="paragraph">The graph has 2 edge types, which are <a href='https://biolink.github.io/biolink-model/docs/in_taxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:in_taxon'>biolink:in_taxon</a> (1.07M edges, 52.24%) and <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:s ...
# <li><p class="paragraph">Chain containing 20 nodes and starts from the node <a href='https://www.wikidata.org/wiki/Q21353733' target='_blank' title='Go to WikiData to get more informations about wd:Q21353733'>wd:Q21353733</a>. Specifically, the nodes involved in the chain are: <a href='https://www.wikidata.org/wiki/Q189069' target='_blank' title='Go to WikiData to get more informations about wd:Q189069'>wd:Q189069</a>, <a href='https://www.wikidata.org/wiki/Q1349838' target='_blank' title='Go to WikiData to get more informations about wd:Q1349838'>wd:Q1349838</a>, <a href='https://www.wikidata.org/wiki/Q930410' target='_blank' title='Go to WikiData to get more informations about wd:Q930410'>wd:Q930410</a>, <a href='https://www.wikidata.org/wiki/Q5853182' target='_blank' title='Go to WikiData to get more informations about wd:Q5853182'>wd:Q5853182</a>, <a href='https://www.wikidata.org/wiki/Q322241' target='_blank' title='Go to WikiData to get more informations about wd:Q322241'>wd:Q322241</a> and other 14. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Chain containing 12 nodes and starts from the node <a href='https://www.wikidata.org/wiki/Q185038' target='_blank' title='Go to WikiData to get more informations about wd:Q185038'>wd:Q185038</a>. Specifically, the nodes involved in the chain are: <a href='https://www.wikidata.org/wiki/Q2372824' target='_blank' title='Go to WikiData to get more informations about wd:Q2372824'>wd:Q2372824</a>, <a href='https://www.wikidata.org/wiki/Q5359418' target='_blank' title='Go to WikiData to get more informations about wd:Q5359418'>wd:Q5359418</a>, <a href='https://www.wikidata.org/wiki/Q20686726' target='_blank' title='Go to WikiData to get more informations about wd:Q20686726'>wd:Q20686726</a>, <a href='https://www.wikidata.org/wiki/Q23926871' target='_blank' title='Go to WikiData to get more informations about wd:Q23926871'>wd:Q23926871</a>, <a href='https://www.wikidata.org/wiki/Q19561774' target='_blank' title='Go to WikiData to get more informations about wd:Q19561774'>wd:Q19561774</a> and other 6. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Chain containing 11 nodes and starts from the node <a href='https://www.wikidata.org/wiki/Q2742285' target='_blank' title='Go to WikiData to get more informations about wd:Q2742285'>wd:Q2742285</a>. Specifically, the nodes involved in the chain are: <a href='https://www.wikidata.org/wiki/Q1844946' target='_blank' title='Go to WikiData to get more informations about wd:Q1844946'>wd:Q1844946</a>, <a href='https://www.wikidata.org/wiki/Q10748156' target='_blank' title='Go to WikiData to get more informations about wd:Q10748156'>wd:Q10748156</a>, <a href='https://www.wikidata.org/wiki/Q13362187' target='_blank' title='Go to WikiData to get more informations about wd:Q13362187'>wd:Q13362187</a>, <a href='https://www.wikidata.org/wiki/Q4869200' target='_blank' title='Go to WikiData to get more informations about wd:Q4869200'>wd:Q4869200</a>, <a href='https://www.wikidata.org/wiki/Q131863' target='_blank' title='Go to WikiData to get more informations about wd:Q131863'>wd:Q131863</a> and other 5. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><h4 style="margin: 1em 0 0 0;">Isomorphic node groups</h4><p class="paragraph">Isomorphic node groups are nodes with exactly the same neighbours, node types, edge types and weights (if present in the graph). Nodes in such groups are topologically indistinguishable, that is swapping their ID would not change the graph topology. We have detected 441 isomorphic node groups in the graph, involving a total of 981 nodes (0.36%) and 25.30K edges (1.24%), with the largest one involving 16 nodes and 1.15K edges. The detected isomorphic node groups, sorted by decreasing size, are:</p><ol class="medium-columns"><li><p class="paragraph">Group with 2 nodes (degree 573 and node type <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>): <a href='https://www.wikidata.org/wiki/Q20686225' target='_blank' title='Go to WikiData to get more informations about wd:Q20686225'>wd:Q20686225</a> and <a href='https://www.wikidata.org/wiki/Q125337' target='_blank' title='Go to WikiData to get more informations about wd:Q125337'>wd:Q125337</a>.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 244 and node type <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>): <a href='https://www.wikidata.org/wiki/Q80024' target='_blank' title='Go to WikiData to get more informations about wd:Q80024'>wd:Q80024</a> and <a href='https://www.wikidata.org/wiki/Q21004587' target='_blank' title='Go to WikiData to get more informations about wd:Q21004587'>wd:Q21004587</a>.</p></li>
# <li><p class="paragraph">Group with 16 nodes (degree 26 and node type <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>): <a href='https://www.wikidata.org/wiki/Q1632103' target='_blank' title='Go to WikiData to get more informations about wd:Q1632103'>wd:Q1632103</a>, <a href='https://www.wikidata.org/wiki/Q38451321' target='_blank' title='Go to WikiData to get more informations about wd:Q38451321'>wd:Q38451321</a>, <a href='https://www.wikidata.org/wiki/Q21273612' target='_blank' title='Go to WikiData to get more informations about wd:Q21273612'>wd:Q21273612</a>, <a href='https://www.wikidata.org/wiki/Q147318' target='_blank' title='Go to WikiData to get more informations about wd:Q147318'>wd:Q147318</a>, <a href='https://www.wikidata.org/wiki/Q1462918' target='_blank' title='Go to WikiData to get more informations about wd:Q1462918'>wd:Q1462918</a> and other 11.</p></li>
# <li><p class="paragraph">Group with 6 nodes (degree 69 and node type <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>): <a href='https://www.wikidata.org/wiki/Q5405632' target='_blank' title='Go to WikiData to get more informations about wd:Q5405632'>wd:Q5405632</a>, <a href='https://www.wikidata.org/wiki/Q5405595' target='_blank' title='Go to WikiData to get more informations about wd:Q5405595'>wd:Q5405595</a>, <a href='https://www.wikidata.org/wiki/Q7212982' target='_blank' title='Go to WikiData to get more informations about wd:Q7212982'>wd:Q7212982</a>, <a href='https://www.wikidata.org/wiki/Q7212840' target='_blank' title='Go to WikiData to get more informations about wd:Q7212840'>wd:Q7212840</a>, <a href='https://www.wikidata.org/wiki/Q15396633' target='_blank' title='Go to WikiData to get more informations about wd:Q15396633'>wd:Q15396633</a> and another one.</p></li>
# <li><p class="paragraph">Group with 2 nodes (degree 196 and node type <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a
</p><h4 style="margin: 1em 0 0 0;">Dendritic trees</h4><p class="paragraph">A dendritic tree is a tree-like structure starting from a root node that is part of another strongly connected component. We have detected 91 dendritic trees in the graph, involving a total of 1.71K nodes (0.62%) and 3.42K edges (0.17%), with the largest one involving 512 nodes and 1.02K edges. The detected dendritic trees, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0000424 (degree 24), and containing 512 nodes, with a maximal depth of 2, which are CHEMONTID:0000438 (degree 6), CHEMONTID:0000439 (degree 6), CHEMONTID:0000440 (degree 6), CHEMONTID:0000441 (degree 6) and CHEMONTID:0000442 (degree 6). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0000002 (degree 262), and containing 171 nodes, with a maximal depth of 4, which are CHEMONTID:0000068 (degree 4), CHEMONTID:0000092, CHEMONTID:0000096, CHEMONTID:0000104 and CHEMONTID:0000224. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0000264 (degree 86), and containing 75 nodes, with a maximal depth of 3, which are CHEMONTID:0000464, CHEMONTID:0000488 (degree 3), CHEMONTID:0000498 (degree 3), CHEMONTID:0001163 and CHEMONTID:0001236 (degree 3). Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0000463 (degree 49), and containing 51 nodes, with a maximal depth of 3, which are CHEMONTID:0000230, CHEMONTID:0000395 (degree 4), CHEMONTID:0000396 (degree 3), CHEMONTID:0000466 and CHEMONTID:0001153. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0000462 (degree 11), and containing 51 nodes, with a maximal depth of 4, which are CHEMONTID:0000277, CHEMONTID:0001371 (degree 8), CHEMONTID:0001372, CHEMONTID:0001523 (degree 5) and CHEMONTID:0004436. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tree starting from the root node CHEMONTID:0003737 (degree 44), and containing 42 nodes, with a maximal depth of 3, which are CHEMONTID:0001134, CHEMONTID:0003703, CHEMONTID:0003704, CHEMONTID:0003705 and CHEMONTID:0003706. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 85 dendritic trees.</p><h4 style="margin: 1em 0 0 0;">Dendritic stars</h4><p class="paragraph">A dendritic star is a dendritic tree with a maximal depth of one, where nodes with maximal unique degree one are connected to a central root node with high degree and inside a strongly connected component. We have detected 259 dendritic stars in the graph, involving a total of 1.02K nodes (0.37%) and 2.03K edges (0.10%), with the largest one involving 79 nodes and 158 edges. The detected dendritic stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic star starting from the root node <a href='https://www.wikidata.org/wiki/Q310738' target='_blank' title='Go to WikiData to get more informations about wd:Q310738'>wd:Q310738</a> (degree 135), and containing 79 nodes, with a maximal depth of 1, which are <a href='https://www.wikidata.org/wiki/Q10454069' target='_blank' title='Go to WikiData to get more informations about wd:Q10454069'>wd:Q10454069</a>, <a href='https://www.wikidata.org/wiki/Q10454155' target='_blank' title='Go to WikiData to get more informations about wd:Q10454155'>wd:Q10454155</a>, <a href='https://www.wikidata.org/wiki/Q10454227' target='_blank' title='Go to WikiData to get more informations about wd:Q10454227'>wd:Q10454227</a>, <a href='https://www.wikidata.org/wiki/Q10454257' target='_blank' title='Go to WikiData to get more informations about wd:Q10454257'>wd:Q10454257</a> and <a href='https://www.wikidata.org/wiki/Q105492598' target='_blank' title='Go to WikiData to get more informations about wd:Q105492598'>wd:Q105492598</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='https://www.wikidata.org/wiki/Q310585' target='_blank' title='Go to WikiData to get more informations about wd:Q310585'>wd:Q310585</a> (degree 47), and containing 27 nodes, with a maximal depth of 1, which are <a href='https://www.wikidata.org/wiki/Q10510484' target='_blank' title='Go to WikiData to get more informations about wd:Q10510484'>wd:Q10510484</a>, <a href='https://www.wikidata.org/wiki/Q105497509' target='_blank' title='Go to WikiData to get more informations about wd:Q105497509'>wd:Q105497509</a>, <a href='https://www.wikidata.org/wiki/Q108131293' target='_blank' title='Go to WikiData to get more informations about wd:Q108131293'>wd:Q108131293</a>, <a href='https://www.wikidata.org/wiki/Q108131523' target='_blank' title='Go to WikiData to get more informations about wd:Q108131523'>wd:Q108131523</a> and <a href='https://www.wikidata.org/wiki/Q108132918' target='_blank' title='Go to WikiData to get more informations about wd:Q108132918'>wd:Q108132918</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node CHEMONTID:0000435 (degree 38), and containing 27 nodes, with a maximal depth of 1, which are CHEMONTID:0001048, CHEMONTID:0001049, CHEMONTID:0001050, CHEMONTID:0001051 and CHEMONTID:0001052. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node CHEMONTID:0001813 (degree 33), and containing 26 nodes, with a maximal depth of 1, which are CHEMONTID:0001815, CHEMONTID:0001901, CHEMONTID:0001902, CHEMONTID:0001940 and CHEMONTID:0001941. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node CHEMONTID:0000279 (degree 711), and containing 20 nodes, with a maximal depth of 1, which are CHEMONTID:0001390, CHEMONTID:0001783, CHEMONTID:0001784, CHEMONTID:0001785 and CHEMONTID:0001793. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic star starting from the root node <a href='https://www.wikidata.org/wiki/Q310915' target='_blank' title='Go to WikiData to get more informations about wd:Q310915'>wd:Q310915</a> (degree 94), and containing 19 nodes, with a maximal depth of 1, which are <a href='https://www.wikidata.org/wiki/Q109578888' target='_blank' title='Go to WikiData to get more informations about wd:Q109578888'>wd:Q109578888</a>, <a href='https://www.wikidata.org/wiki/Q109579035' target='_blank' title='Go to WikiData to get more informations about wd:Q109579035'>wd:Q109579035</a>, <a href='https://www.wikidata.org/wiki/Q109579086' target='_blank' title='Go to WikiData to get more informations about wd:Q109579086'>wd:Q109579086</a>, <a href='https://www.wikidata.org/wiki/Q109579145' target='_blank' title='Go to WikiData to get more informations about wd:Q109579145'>wd:Q109579145</a> and <a href='https://www.wikidata.org/wiki/Q109579164' target='_blank' title='Go to WikiData to get more informations about wd:Q109579164'>wd:Q109579164</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 253 dendritic stars.</p><h4 style="margin: 1em 0 0 0;">Dendritic tendril stars</h4><p class="paragraph">A dendritic tendril star is a dendritic tree with a depth greater than one, where the arms of the star are tendrils. We have detected 37 dendritic tendril stars in the graph, involving a total of 208 nodes (0.08%) and 416 edges (0.02%), with the largest one involving 19 nodes and 38 edges. The detected dendritic tendril stars, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Dendritic tendril star starting from the root node <a href='https://www.wikidata.org/wiki/Q662144' target='_blank' title='Go to WikiData to get more informations about wd:Q662144'>wd:Q662144</a> (degree 50), and containing 19 nodes, with a maximal depth of 2, which are <a href='https://www.wikidata.org/wiki/Q10495325' target='_blank' title='Go to WikiData to get more informations about wd:Q10495325'>wd:Q10495325</a>, <a href='https://www.wikidata.org/wiki/Q10524857' target='_blank' title='Go to WikiData to get more informations about wd:Q10524857'>wd:Q10524857</a>, <a href='https://www.wikidata.org/wiki/Q105499307' target='_blank' title='Go to WikiData to get more informations about wd:Q105499307'>wd:Q105499307</a>, <a href='https://www.wikidata.org/wiki/Q10648701' target='_blank' title='Go to WikiData to get more informations about wd:Q10648701'>wd:Q10648701</a> and <a href='https://www.wikidata.org/wiki/Q10648709' target='_blank' title='Go to WikiData to get more informations about wd:Q10648709'>wd:Q10648709</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node CHEMONTID:0003865 (degree 18), and containing 17 nodes, with a maximal depth of 2, which are CHEMONTID:0000126, CHEMONTID:0003920, CHEMONTID:0003921, CHEMONTID:0003929 and CHEMONTID:0003930. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node CHEMONTID:0002052 (degree 15), and containing 14 nodes, with a maximal depth of 2, which are CHEMONTID:0000065, CHEMONTID:0000085, CHEMONTID:0000300, CHEMONTID:0000345 and CHEMONTID:0000742. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node CHEMONTID:0001553 (degree 9.91K), and containing 14 nodes, with a maximal depth of 2, which are CHEMONTID:0000180, CHEMONTID:0001351, CHEMONTID:0002190, CHEMONTID:0002400 and CHEMONTID:0002884. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node CHEMONTID:0001253 (degree 103), and containing 11 nodes, with a maximal depth of 2, which are CHEMONTID:0000239, CHEMONTID:0001513, CHEMONTID:0003910, CHEMONTID:0003912 and CHEMONTID:0004083. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Dendritic tendril star starting from the root node CHEMONTID:0003026 (degree 10), and containing 9 nodes, with a maximal depth of 2, which are CHEMONTID:0002972, CHEMONTID:0002974, CHEMONTID:0002975, CHEMONTID:0002986 and CHEMONTID:0003245. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/ChemicalEntity.html' target='_blank' title='Go to BioLink to get more informations about biolink:ChemicalEntity'>biolink:ChemicalEntity</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li></ol><p class="paragraph">And other 31 dendritic tendril stars.</p><h4 style="margin: 1em 0 0 0;">Tendrils</h4><p class="paragraph">A tendril is a path starting from a node of degree one, connected to a strongly connected component. We have detected 504 tendrils in the graph, involving a total of 598 nodes (0.22%) and 1.20K edges (0.06%), with the largest one involving 7 nodes and 14 edges. The detected tendrils, sorted by decreasing size, are:</p><ol class="large-columns"><li><p class="paragraph">Tendril starting from the root node <a href='https://www.wikidata.org/wiki/Q185631' target='_blank' title='Go to WikiData to get more informations about wd:Q185631'>wd:Q185631</a> (degree 3), and containing 7 nodes, with a maximal depth of 7, which are <a href='https://www.wikidata.org/wiki/Q275879' target='_blank' title='Go to WikiData to get more informations about wd:Q275879'>wd:Q275879</a>, <a href='https://www.wikidata.org/wiki/Q9293731' target='_blank' title='Go to WikiData to get more informations about wd:Q9293731'>wd:Q9293731</a>, <a href='https://www.wikidata.org/wiki/Q6901978' target='_blank' title='Go to WikiData to get more informations about wd:Q6901978'>wd:Q6901978</a>, <a href='https://www.wikidata.org/wiki/Q18668429' target='_blank' title='Go to WikiData to get more informations about wd:Q18668429'>wd:Q18668429</a> and <a href='https://www.wikidata.org/wiki/Q3824165' target='_blank' title='Go to WikiData to get more informations about wd:Q3824165'>wd:Q3824165</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www.wikidata.org/wiki/Q756153' target='_blank' title='Go to WikiData to get more informations about wd:Q756153'>wd:Q756153</a> (degree 7), and containing 5 nodes, with a maximal depth of 5, which are <a href='https://www.wikidata.org/wiki/Q232936' target='_blank' title='Go to WikiData to get more informations about wd:Q232936'>wd:Q232936</a>, <a href='https://www.wikidata.org/wiki/Q1306572' target='_blank' title='Go to WikiData to get more informations about wd:Q1306572'>wd:Q1306572</a>, <a href='https://www.wikidata.org/wiki/Q3373084' target='_blank' title='Go to WikiData to get more informations about wd:Q3373084'>wd:Q3373084</a>, <a href='https://www.wikidata.org/wiki/Q3373168' target='_blank' title='Go to WikiData to get more informations about wd:Q3373168'>wd:Q3373168</a> and <a href='https://www.wikidata.org/wiki/Q1225000' target='_blank' title='Go to WikiData to get more informations about wd:Q1225000'>wd:Q1225000</a>. Its nodes have a single node type, which is <a href='https://biolink.github.io/biolink-model/docs/OrganismTaxon.html' target='_blank' title='Go to BioLink to get more informations about biolink:OrganismTaxon'>biolink:OrganismTaxon</a>. Its edges have a single edge type, which is <a href='https://biolink.github.io/biolink-model/docs/subclass_of.html' target='_blank' title='Go to BioLink to get more informations about biolink:subclass_of'>biolink:subclass_of</a>.</p></li>
# <li><p class="paragraph">Tendril starting from the root node <a href='https://www